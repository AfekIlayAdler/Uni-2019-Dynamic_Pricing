# %% [markdown]
# ### last modified in 10-06-2019 19:00 by Afek Ilay Adler

# %% [markdown]
# # **A. Imports**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

"""
Notice: ignore warnings is suitable for display but not preferred when writing code
"""
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **B.First glence of the data**

# %%
df = pd.read_csv('avocado.csv',index_col = 0)
SEED = 4
np.random.seed(SEED)
def first_glence(df):
    """
    suitable only for jupyter because the display function doesn't exist in python
    :param df: pandas_dataframe
    :param save_csv: if dave the details to csv
    :return: None
    """
    frames = {}
    frames['head'] = df.head(2)
    frames['missing_values'] = df.isna().sum() / df.shape[0]
    frames['dtypes'] = df.dtypes
    frames.update({dtype: df.select_dtypes(include=[dtype]).describe() for dtype in df.dtypes.unique()})
    for frame_name, frame in frames.items():
        print('{} :'.format(frame_name))
        print("***" * 10)
        display(frame)
        print('\n')
first_glence(df)
# Out:
# head :
# ******************************
#          Date  AveragePrice  Total Volume     4046      4225   4770  \
# 0  2015-12-27          1.33      64236.62  1036.74  54454.85  48.16
# 1  2015-12-20          1.35      54876.98   674.28  44638.81  58.33
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# missing_values :
# ******************************
# Date            0.0
# AveragePrice    0.0
# Total Volume    0.0
# 4046            0.0
# 4225            0.0
# 4770            0.0
# Total Bags      0.0
# Small Bags      0.0
# Large Bags      0.0
# XLarge Bags     0.0
# type            0.0
# year            0.0
# region          0.0
# dtype: float64
# dtypes :
# ******************************
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object
# object :
# ******************************
#               Date          type         region
# count        18249         18249          18249
# unique         169             2             54
# top     2015-11-08  conventional  PhoenixTucson
# freq           108          9126            338
# float64 :
# ******************************
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
# int64 :
# ******************************
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %% [markdown]
# # **#1**

# %% [markdown]
# ### **Exploratory data analysis on the chosen data set, as you see fit, and use of  regression to provide some insights into the key effects you observe. To wit, what explanatory variables impact the dependent variable, their statistical significance, and the extent to which the dependent variable is sensitive to changes in these variables (including elasticity estimates).**

# %% [markdown]
# ### There are ~50 region:
# 1. We focus on 8 regions in the east coast
# 2. The type column indicates the type of the avocado - there are regular and organic ones

# %%
print ('unique regions: ')
display(df.region.unique())
# we choose to focus on some main cities in the us east coast
cities = ['Atlanta','Boston','Chicago','Detroit', 'Orlando', 'Philadelphia','NewYork','Nashville']
df = df[df.region.isin(cities)]
df_conventional = df[df.type == 'conventional']
df_organic = df[df.type == 'organic']
print ('we will focus on these regions: {}'.format(cities))
# Out:
# unique regions:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)
# we will focus on these regions: ['Atlanta', 'Boston', 'Chicago', 'Detroit', 'Orlando', 'Philadelphia', 'NewYork', 'Nashville']

# %% [markdown]
# ### CORREALATION PLOT
# #### of the total volume avocado sold in (2015-2019)

# %%
corr = df_conventional.pivot('Date','region','Total Volume').corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(10, 7))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Demand as function of the price:
# 1. regular Avocados
# 2. organic avocado

# %%
plt.figure(figsize=(10,7))
ax = sns.lineplot(data = df_conventional, x = 'AveragePrice', y ='Total Volume')
ax.set_title("Demand as function of the price for regular Avocados", size = 15)
ax.set_xlim(0.5,2.25)

plt.figure(figsize=(10,7))
ax = sns.lineplot(data = df_organic, x = 'AveragePrice', y ='Total Volume' )
ax.set_title("Demand as function of the price for organic Avocados", size = 15)
ax.set_xlim(0.5,2.25)
# Out:
# (0.5, 2.25)

# %% [markdown]
# ### We will choose to focus either on 4225 Avocados sold or Total Volume sold
# #### let's plot their volumein order to understand which one is more "intersting"

# %%
g = sns.FacetGrid(df_conventional, col= "region",col_wrap=4, height = 5)
g.map(sns.lineplot,'AveragePrice', '4225' )
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Demand function of the price for regular 4225 Avocados \n By city', size = 15)
# Out:
# Text(0.5, 0.98, 'Demand function of the price for regular 4225 Avocados \n By city')

# %%
g = sns.FacetGrid(df_conventional, col= "region",col_wrap=4, height = 5)
g.map(sns.lineplot,'AveragePrice', 'Total Volume' )
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Demand function of the price for Total Volume of Avocados \n By city', size = 15)
# Out:
# Text(0.5, 0.98, 'Demand function of the price for Total Volume of Avocados \n By city')

# %% [markdown]
# ### Based on the above graphs We will choose to focus on Total Volume sold because some cities don't cell 4225 avocados

# %% [markdown]
# ### Add temporal columns and plot temporal relations

# %%
df_conventional = df_conventional[['Date','AveragePrice','Total Volume','year','region']]
df_conventional.Date = df_conventional.Date.astype('datetime64')
df_conventional['month'] = df_conventional.Date.dt.month
df_conventional['week'] = df_conventional.Date.dt.week
df_conventional.head()
# Out:
#         Date  AveragePrice  Total Volume  year   region  month  week
# 0 2015-12-27          0.99     386100.49  2015  Atlanta     12    52
# 1 2015-12-20          1.08     331377.53  2015  Atlanta     12    51
# 2 2015-12-13          0.96     417772.47  2015  Atlanta     12    50
# 3 2015-12-06          1.07     357636.82  2015  Atlanta     12    49
# 4 2015-11-29          0.99     333280.79  2015  Atlanta     11    48

# %%
g = sns.FacetGrid(df_conventional, col= "region",col_wrap=4, height = 5)
g.map(sns.lineplot,'week', 'Total Volume' )
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Total Volume of Avocados By week \n By city', size = 15)
# Out:
# Text(0.5, 0.98, 'Total Volume of Avocados By week \n By city')

# %%
g = sns.FacetGrid(df_conventional, col= "region",col_wrap=4, height = 5)
g.map(sns.barplot,'year', 'Total Volume',ci=None, palette = sns.color_palette())

# %%
g = sns.FacetGrid(df_conventional, col= "region",col_wrap=4, height = 5)
g.map(sns.barplot,'month', 'Total Volume',ci=None, palette = sns.color_palette())

# %% [markdown]
# ### Running ordinary least squares regression in order to estimate demand
# ##### Of course, we can use more complicated regressors such as neural nets, svm,
# ##### but then it will be more complex to find the best price

# %%
X = df_conventional[['region','month','AveragePrice','year']]
for col in ['month','region','year']:
    X[col] = X[col].astype('category')
y = df_conventional['Total Volume']

X_with_dummies = pd.get_dummies(X, drop_first = True)
import statsmodels.api as sm
from scipy import stats
X_with_dummies= sm.add_constant(X_with_dummies)
est = sm.OLS(y, X_with_dummies)
est = est.fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Total Volume   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     589.0
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):               0.00
# Time:                        00:30:32   Log-Likelihood:                -17676.
# No. Observations:                1352   AIC:                         3.540e+04
# Df Residuals:                    1329   BIC:                         3.552e+04
# Df Model:                          22
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                8.872e+05   2.09e+04     42.489      0.000    8.46e+05    9.28e+05
# AveragePrice        -4.586e+05   1.81e+04    -25.293      0.000   -4.94e+05   -4.23e+05
# region_Boston        1.568e+05   1.33e+04     11.747      0.000    1.31e+05    1.83e+05
# region_Chicago       3.849e+05   1.38e+04     27.950      0.000    3.58e+05    4.12e+05
# region_Detroit       -1.28e+05   1.27e+04    -10.094      0.000   -1.53e+05   -1.03e+05
# region_Nashville    -3.358e+05   1.27e+04    -26.471      0.000   -3.61e+05   -3.11e+05
# region_NewYork       1.011e+06    1.4e+04     72.158      0.000    9.84e+05    1.04e+06
# region_Orlando      -1.041e+05   1.29e+04     -8.061      0.000   -1.29e+05   -7.88e+04
# region_Philadelphia  4.854e+04    1.4e+04      3.475      0.001    2.11e+04    7.59e+04
# month_2              4.736e+04   1.42e+04      3.343      0.001    1.96e+04    7.51e+04
# month_3              1.056e+04    1.4e+04      0.755      0.450   -1.69e+04     3.8e+04
# month_4              2.941e+04   1.54e+04      1.907      0.057    -844.916    5.97e+04
# month_5              1.218e+05    1.5e+04      8.120      0.000    9.24e+04    1.51e+05
# month_6              9.292e+04   1.57e+04      5.901      0.000     6.2e+04    1.24e+05
# month_7              6.616e+04   1.53e+04      4.338      0.000    3.62e+04    9.61e+04
# month_8              5.582e+04   1.56e+04      3.573      0.000    2.52e+04    8.65e+04
# month_9               4.89e+04   1.62e+04      3.021      0.003    1.72e+04    8.07e+04
# month_10             3.248e+04    1.6e+04      2.027      0.043    1038.541    6.39e+04
# month_11            -2.706e+04   1.55e+04     -1.742      0.082   -5.75e+04    3409.852
# month_12            -4.922e+04   1.53e+04     -3.225      0.001   -7.92e+04   -1.93e+04
# year_2016            5.428e+04   8133.332      6.673      0.000    3.83e+04    7.02e+04
# year_2017            1.489e+05   9277.271     16.053      0.000    1.31e+05    1.67e+05
# year_2018            2.516e+05   1.47e+04     17.114      0.000    2.23e+05     2.8e+05
# ==============================================================================
# Omnibus:                     1088.820   Durbin-Watson:                   1.348
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            56057.447
# Skew:                           3.315   Prob(JB):                         0.00
# Kurtosis:                      33.841   Cond. No.                         20.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Create a normalized 'Total Volume' column for future analysis and save to_csv
# ### The normalization is StandardScaler (Z score) per city

# %%
X_norm = df_conventional[['Date','region','month','AveragePrice','year' ,'Total Volume']]
stats_dict = X_norm[['region','Total Volume']].groupby('region').agg(['mean','std'])['Total Volume'].to_dict()
def norm_row(row):
    return (row['Total Volume'] - stats_dict['mean'][row['region']])/stats_dict['std'][row['region']]
X_norm['Total_Volume_Norm'] = X_norm.apply(norm_row, axis = 1)
X_norm.to_csv('avocado_dataset_filtered.csv')

# %% [markdown]
# ### Now after normalizaton we expect the graphs to be more simmiliar

# %%
g = sns.FacetGrid(X_norm , col= "region",col_wrap=4, height = 5)
g.map(sns.lineplot,'AveragePrice', 'Total_Volume_Norm' )
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Demand function of the price for Total Volume of Avocados (Normalized) \n By city', size = 15) 
sns.lineplot(data = X_norm,x = 'AveragePrice', y = 'Total_Volume_Norm' )

# %%
plt.figure(figsize=(10,7))
ax = sns.lineplot(data = X_norm,x = 'AveragePrice', y = 'Total_Volume_Norm' )
ax.set_title("Demand as function of the price for Total_Volume_Norm", size = 15)
ax.set_xlim(0.5,2.25)
# Out:
# (0.5, 2.25)

# %% [markdown]
# ### Estimation of Elasticity of Demand for all cities together

# %%
regression_df= pd.DataFrame()
regression_df['x'] = np.log(X_norm['AveragePrice'])
regression_df['y'] = np.log(X_norm['Total_Volume_Norm'])
X = regression_df.dropna()['x']
plt.figure(figsize=(10,7))
ax = sns.regplot(x= X , y= regression_df.dropna()['y'] , color="g")
ax.set_title("Demand as function of the price for Total_Volume_Norm", size = 15)
X = sm.add_constant(X)
est = sm.OLS(regression_df.dropna()['y'],X)
est = est.fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     101.2
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):           4.72e-22
# Time:                        00:30:47   Log-Likelihood:                -917.05
# No. Observations:                 580   AIC:                             1838.
# Df Residuals:                     578   BIC:                             1847.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4474      0.055     -8.143      0.000      -0.555      -0.340
# x             -2.5201      0.250    -10.061      0.000      -3.012      -2.028
# ==============================================================================
# Omnibus:                      206.575   Durbin-Watson:                   1.590
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              944.641
# Skew:                          -1.547   Prob(JB):                    7.48e-206
# Kurtosis:                       8.433   Cond. No.                         5.17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# # we can see that the elasticity in ~2.5

# %% [markdown]
# ### Estimation of Elasticity of Demand for all cities separately

# %%
for city in X_norm.region.unique():
    frame = X_norm[X_norm.region == city]
    regression_df = pd.DataFrame()
    regression_df['x'] = np.log(frame['AveragePrice'])
    regression_df['y'] = np.log(frame['Total_Volume_Norm'])
    X = regression_df.dropna()['x']
    X = sm.add_constant(X)
    est = sm.OLS(regression_df.dropna()['y'],X)
    est = est.fit()
    print('#####'*10)
    print(city)
    print(np.abs(est.params['x']))
# Out:
# ##################################################
# Atlanta
# 4.113635273510457
# ##################################################
# Boston
# 2.561369819243075
# ##################################################
# Chicago
# 2.6809302750929547
# ##################################################
# Detroit
# 6.760771864851739
# ##################################################
# Nashville
# 3.333714912498329
# ##################################################
# NewYork
# 4.344748226318521
# ##################################################
# Orlando
# 3.2216916337293044
# ##################################################
# Philadelphia
# 5.630464903671253

# %% [markdown]
# # **#2**

# %% [markdown]
# ### **Formulation of a demand function model which is based on the regression you have run, and optimization of the estimated model to arrive at the  estimated optimal static price for your set up.**

# %% [markdown]
# ### The demand function is linear in the input (X) as formulated in the linear regression above.
# ### as a generalization of excercise 1 the - estimated optimal static price ;
#
# \begin{equation*}
# \hat p
# = \frac{a +b_1x_1+ b_2x_2 \cdots + b_{n-1}x_{n-1}}{2b_n}
# \end{equation*}
#
# where $b_n$  is the coefficent of  $p$

# %% [markdown]
# # **#3**

# %% [markdown]
# ### **Analysis  of  variation  and  spread  in  observed  prices  relative  to  what  you computed to bethe optimal price based on your model.**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from math import sqrt

CV = 5
lr = LinearRegression()
parameters = {}
clf = GridSearchCV(lr, parameters, cv=CV, scoring = 'r2')
clf.fit(X_with_dummies, y)
print ('cross validation results')
display(clf.cv_results_)

reg_linear = clf.best_estimator_
error = y-reg_linear.predict(X_with_dummies)
plt.figure(figsize=(10,7))
ax = sns.distplot(error)
ax.set_title("Linear Regression - Error Distribution", size = 15)

plt.figure(figsize=(10,7))
ax = sns.regplot(x= X_with_dummies['AveragePrice'], y= error)
ax.set_title("Linear Regression - Error as Function of The Price", size = 15)

plt.figure(figsize=(10,7))
ax = sns.regplot(x= y, y= reg_linear.predict(X_with_dummies))
ax.set_title("Linear Regression - Y True vs Predicted Y", size = 15)

# compute rmse
rmse = sqrt(mean_squared_error(y, reg_linear.predict(X_with_dummies)))
print ('rmse is : {}'.format(rmse))
# Out:
# cross validation results
# {'mean_fit_time': array([0.00578442]),
#  'std_fit_time': array([0.00212991]),
#  'mean_score_time': array([0.00199442]),
#  'std_score_time': array([0.0006306]),
#  'params': [{}],
#  'split0_test_score': array([0.89436505]),
#  'split1_test_score': array([0.93669825]),
#  'split2_test_score': array([0.92050724]),
#  'split3_test_score': array([0.80453854]),
#  'split4_test_score': array([0.77310931]),
#  'mean_test_score': array([0.86591718]),
#  'std_test_score': array([0.06506941]),
#  'rank_test_score': array([1]),
#  'split0_train_score': array([0.90630794]),
#  'split1_train_score': array([0.89975257]),
#  'split2_train_score': array([0.90090843]),
#  'split3_train_score': array([0.91004322]),
#  'split4_train_score': array([0.92245522]),
#  'mean_train_score': array([0.90789348]),
#  'std_train_score': array([0.00817612])}
# rmse is : 115248.80031864325

# %% [markdown]
# ### Analysis of the results # 1
# In the first graph we can see that the distribution of errors is centered around 0.
# In the second graph we can see that there is no clear connection between the price and the error
# But in the third graph we can clearly see that there are certain places where the linear model is underfits.
# we believe that we can improve this results in two major ways:
#     1. apply log transformation to y values and then apply the regression - we will show that y values
#     are skewed to the right so a log transformation can be better.
#     2. try more complex models so in order to lower the bias of the model
# we will use the first approach.

# %%
ax = sns.distplot(y)
ax.set_title("y Distribution is right skewed", size = 15)
# Out:
# Text(0.5, 1.0, 'y Distribution is right skewed')

# %% [markdown]
# ### **Log linear model**

# %%
CV = 5
lr = LinearRegression()
parameters = {}
clf = GridSearchCV(lr, parameters, cv=CV, scoring = 'r2')
y = np.log(y)
clf.fit(X_with_dummies,y)
print ('cross validation results')
display(clf.cv_results_)

reg = clf.best_estimator_
error = y-reg.predict(X_with_dummies)
plt.figure(figsize=(10,7))
ax = sns.distplot(error)
ax.set_title("Log Linear Regression - Error Distribution", size = 15)

plt.figure(figsize=(10,7))
ax = sns.regplot(x= X_with_dummies['AveragePrice'], y= error)
ax.set_title("Log Linear Regression - Error as Function of The Price", size = 15)

plt.figure(figsize=(10,7))
ax = sns.regplot(x= y, y= reg.predict(X_with_dummies))
ax.set_title("Log Linear Regression - Y True vs Predicted Y", size = 15)

# compute rmse
rmse = sqrt(mean_squared_error(y, reg.predict(X_with_dummies)))
print ('rmse is : {}'.format(rmse))
# Out:
# cross validation results
# {'mean_fit_time': array([0.00534949]),
#  'std_fit_time': array([0.00337424]),
#  'mean_score_time': array([0.00099726]),
#  'std_score_time': array([2.37661112e-05]),
#  'params': [{}],
#  'split0_test_score': array([0.95549303]),
#  'split1_test_score': array([0.93759399]),
#  'split2_test_score': array([0.9672587]),
#  'split3_test_score': array([0.92486575]),
#  'split4_test_score': array([0.74479224]),
#  'mean_test_score': array([0.90606072]),
#  'std_test_score': array([0.08186249]),
#  'rank_test_score': array([1]),
#  'split0_train_score': array([0.95764308]),
#  'split1_train_score': array([0.96074342]),
#  'split2_train_score': array([0.9537945]),
#  'split3_train_score': array([0.96204443]),
#  'split4_train_score': array([0.96045188]),
#  'mean_train_score': array([0.95893547]),
#  'std_train_score': array([0.00294393])}
# rmse is : 0.11959554531863677

# %% [markdown]
# ### Analysis of the results # 2
# Now the results look much better
# - although the log regression is much better we will focus on the linear regression because we have a closed
# form solution to this problem.

# %% [markdown]
# # **# 4**

# %% [markdown]
# ### **Running an online estimation-optimization algorithm (as we discuss in classes #4 and #5 and as explored a bit in your homework) to optimize prices on the fly. Comparing the resulting price path from this algorithm to the observed prices, and the optimal estimated price (from step 2).**

# %% [markdown]
# ###  **For the sake of simplicity and time considerations we will ignore the fact that every city is different so we will fit another regression**

# %%
x = X_norm[['month','AveragePrice']]
x['month'] = x['month'].astype('category')
x = pd.get_dummies(x,drop_first = True)
x['date'] = X_norm['Date']
x['week'] = x['date'].dt.week
x['year'] = x['date'].dt.year
y = X_norm['Total_Volume_Norm']
cols = ['AveragePrice', 'month_2', 'month_3', 'month_4', 'month_5', 'month_6','month_7', 'month_8', 'month_9', 'month_10', 'month_11', 'month_12']
CV = 5
lr = LinearRegression()
parameters = {}
clf = GridSearchCV(lr, parameters, cv=CV, scoring = 'r2')
x_reg = x[cols]
clf.fit(x_reg,y)
coef = pd.Series(data = clf.best_estimator_.coef_, index =cols).to_dict()
intercept = clf.best_estimator_.intercept_
sigma = np.std(y- clf.predict(x_reg))
print ('estimated std is {}'.format(sigma))
coef
# Out:
# estimated std is 0.8024761387287422
# C:\Users\afeki\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'AveragePrice': -1.3453356535950325,
#  'month_2': 0.4512026349378111,
#  'month_3': -0.08570178623571932,
#  'month_4': -0.24054072141017224,
#  'month_5': 0.4185824250386522,
#  'month_6': 0.17897064996313536,
#  'month_7': -0.07092203094203213,
#  'month_8': -0.24602037185354966,
#  'month_9': -0.36776928468785974,
#  'month_10': -0.6566001335061973,
#  'month_11': -0.887956518143715,
#  'month_12': -0.65132313151597}

# %% [markdown]
# ## The model

# %% [markdown]
# ### Running a simulation for one year - 2017

# %%
class LinearSimulationModel:
    
    def __init__(self,intercept, coef, noise, cols, df):
        self.intercept = intercept
        self.coef = coef
        self.noise = noise
        self.cols = cols
        self.df = df
        self.dates = df['date'].unique()[::-1]
        self.estimated_param_mat = np.zeros((len(self.dates)-1, len(self.coef) +2))
        self.coef_dict = pd.Series(data = coef, index = cols).to_dict()
        self.regret = []
    
    def compute_demand(self,df):
        return df@self.coef + self.intercept + np.random.normal(0,self.noise,8) 
    
    def update_estimated_params(self, week, intercept, coef):
        self.estimated_param_mat[week-1 ,0] = week
        self.estimated_param_mat[week-1 ,1] = intercept
        self.estimated_param_mat[week-1 ,2:len(cols)+2] = coef
        
    def get_coef(self, mat):
        x, y = mat.drop(columns = ['demand']) , mat['demand']
        reg = LinearRegression().fit(x,y)
        return reg.intercept_ , -reg.coef_
    
    def get_new_data(self, date):
        return self.df[self.df.date == date][self.cols]
    
    def get_price(self, intercept , coef, date):
        a = intercept
        c = coef[0]
        if week >= 4:
            cols = list(set(self.cols) - set(['AveragePrice']))
            col = self.df[self.df.date == date][cols].idxmax(axis =1).values[0]
            b = self.coef_dict[col]
            return (a+b)/(-2*c)
        else:
            return a/c
        
    def compute_regret(self, price,date, demand):
        current_revenue = np.mean(price*demand)
        a_true = self.intercept
        cols = [i for i in self.cols if i != 'AveragePrice']
        """
        this part can be done better if we have time
        """
        df = self.df.copy()
        df['b'] = df[cols]@M.coef[1:]
        b_true = df[df.date == date]['b'].values[0]
        c_true = self.coef[0]
        p_optimal = (a_true+b_true)/(-2*c_true)
        # averge demand for 8 cities
        true_demand = a_true +b_true +c_true*p_optimal + np.mean(np.random.normal(0,self.noise,8))
        true_revenue = p_optimal * true_demand
        self.regret.append(true_revenue - current_revenue)
    
                    
simulation_df = x[x.year == 2017]      
coef = clf.best_estimator_.coef_
M = LinearSimulationModel(intercept, coef ,sigma, cols, simulation_df)
P = 2
x1 = M.get_new_data(date = M.dates[0])
x1['AveragePrice'] = P
x1['demand'] = M.compute_demand(x1)

x2 = M.get_new_data(date = M.dates[1])
x2['AveragePrice'] = 2*P
x2['demand'] = M.compute_demand(x2)
observations = pd.concat([x1,x2])
intercept_ , coef_ = M.get_coef(observations)
M.update_estimated_params(1,intercept_ , coef_)

for i,date in enumerate(M.dates[2:]):
    week = i+2
    P = M.get_price(intercept_ , coef_, date)
    temp_mat = M.get_new_data(date = date)
    temp_mat['AveragePrice'] = P
    temp_mat['demand'] = M.compute_demand(temp_mat)
    M.compute_regret(P, date,temp_mat['demand'])
    observations = pd.concat([observations,temp_mat])
    update_params = M.update_estimated_params(week,intercept_ , coef_)
    intercept_ , coef_ =  M.get_coef(observations)

# %% [markdown]
# ### Plot deviation of parameters and regret as a function of time

# %%
columns = ['week','intercept'] + cols
params = pd.DataFrame(M.estimated_param_mat, columns = columns).drop(columns ='week')
parameter_deviation = pd.DataFrame(params.values - np.array([M.intercept] + list(M.coef)), columns = params.columns)
ax = parameter_deviation.plot.line(figsize = (10,7), title = "Prameter Deviation (t)")
ax.set(xlabel='t (weeks)', ylabel='delta')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.figure(figsize=(10,7))
ax = sns.regplot(x = list(range(1,52)),y = np.cumsum((M.regret)))
ax.set_title("Regret(t)", size = 15)
ax.set(xlabel='t (weeks)', ylabel='regret')
# Out:
# [Text(0, 0.5, 'regret'), Text(0.5, 0, 't (weeks)')]

# %% [markdown]
# ### We can see that the parameters vary a lot and dit not converge
# ### As well, we can see that the regret is linear
